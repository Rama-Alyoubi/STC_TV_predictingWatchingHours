# %%
# !pip install pyxlsb

# %%
import pandas as pd
import pyxlsb
import numpy as np

# %%
dataframe = pd.read_excel("/content/stc TV Data Set_T2.xlsb",index_col=0)

# %%
dataframe.shape
# Out:
# (86, 2)

# %%
dataframe.tail()
# Out:
#          date  Total_watch_time_in_houres
# 81 2018-04-24                  652.625278
# 82 2018-04-25                  650.428889
# 83 2018-04-26                  675.184444
# 84 2018-04-27                  601.738056
# 85 2018-04-30                  609.281667

# %%
dataframe.describe()
# Out:
#        Total_watch_time_in_houres
# count                   86.000000
# mean                   780.817926
# std                    122.992002
# min                    562.124722
# 25%                    707.709653
# 50%                    763.181389
# 75%                    840.985278
# max                   1123.551944

# %%
dataframe.isnull().any()
# Out:
# date_                         False
# Total_watch_time_in_houres    False
# dtype: bool

# %%
import matplotlib.pyplot as plt
import plotly
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
dataframe = dataframe.rename(columns={'date_': 'date'})
#dataframe.set_index('date', inplace=True)

# %%
dataframe.head()
# Out:
#         date  Total_watch_time_in_houres
# 0 2018-01-01                 1123.551944
# 1 2018-01-02                 1000.129722
# 2 2018-01-03                  881.924444
# 3 2018-01-04                  782.669444
# 4 2018-01-05                 1051.939444

# %%
dataframe.dtypes
dataframe["date"]= pd.to_datetime(dataframe["date"], format='%Y-%m-%d')

# %%
fig = px.line(dataframe,  y="Total_watch_time_in_houres")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
y = dataframe['Total_watch_time_in_houres'].values
X = dataframe['date'].values
X = X.reshape(-1, 1)
y = y.reshape(-1, 1)
ref_date = np.datetime64('2023-07-13')
X_numeric = [(d - ref_date) / np.timedelta64(1, 'D') for d in X]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_numeric, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

model = ElasticNet(alpha=0.1, l1_ratio=0.5)
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)


print('MSE:', mse)
print('RMSE:', rmse)
print('MAE:', mae)
print('R-squared:', r2)
# Out:
# MSE: 11545.196539995757
# RMSE: 107.44857625857942
# MAE: 88.96860330926671
# R-squared: 0.4635025870755386

# %%
from datetime import datetime, timedelta
future_dates = [datetime.strptime('2018-04-30', '%Y-%m-%d') + timedelta(days=i) for i in range(61)]
future_dates = np.array(future_dates, dtype='datetime64').reshape(-1, 1)

future_X = np.array([(d - ref_date) / np.timedelta64(1, 'D') for d in future_dates]).reshape(-1, 1)

future_y_pred = model.predict(future_X)

for i, date in enumerate(future_y_pred):
    print('Expected watch time for the next two months',future_y_pred[i])
# Out:
# Expected watch time for the next two months 673.6435098717702
# Expected watch time for the next two months 671.7106721434388
# Expected watch time for the next two months 669.7778344151079
# Expected watch time for the next two months 667.844996686777
# Expected watch time for the next two months 665.9121589584461
# Expected watch time for the next two months 663.9793212301151
# Expected watch time for the next two months 662.0464835017842
# Expected watch time for the next two months 660.1136457734533
# Expected watch time for the next two months 658.1808080451219
# Expected watch time for the next two months 656.247970316791
# Expected watch time for the next two months 654.3151325884601
# Expected watch time for the next two months 652.3822948601292
# Expected watch time for the next two months 650.4494571317982
# Expected watch time for the next two months 648.5166194034673
# Expected watch time for the next two months 646.5837816751364
# ...
